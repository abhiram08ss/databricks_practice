# %%
# %sql
DESCRIBE HISTORY databricks_assesment.bronze.stream_bronze_trade_events

# %%
# %sql

SELECT *
FROM databricks_assesment.bronze.stream_bronze_trade_events
WHERE event_ts <
(
    SELECT MAX(event_ts) - INTERVAL 10 MINUTES
    FROM databricks_assesment.bronze.stream_bronze_trade_events
);

# %%
# %sql
DESCRIBE HISTORY databricks_assesment.silver.stream_silver_trades

# %%
# %sql
SELECT *
FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 1

EXCEPT

SELECT *
FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 2;

# %%
# %sql
SELECT COUNT(*)
FROM (
    SELECT *
    FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 2

    EXCEPT

    SELECT *
    FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 1 
);

# %%
# %sql
SELECT COUNT(*) AS count
FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 1;

# %%
# %sql
SELECT COUNT(*) AS count
FROM databricks_assesment.bronze.stream_bronze_trade_events VERSION AS OF 2;

# %%
# %sql
SELECT COUNT(*) AS count
FROM databricks_assesment.bronze.stream_bronze_trade_events

# %%
# %sql
SELECT * FROM databricks_assesment.silver.stream_silver_trades VERSION AS OF 4

EXCEPT

SELECT * FROM databricks_assesment.silver.stream_silver_trades VERSION AS OF 3

# %%
# %sql
SELECT * FROM databricks_assesment.silver.stream_silver_trades VERSION AS OF 2;

# %%
# %sql
SELECT
    MIN(event_time) AS min_event_time,
    MAX(event_time) AS max_event_time,
    COUNT(*) AS total_rows
FROM databricks_assesment.silver.stream_silver_trades;

# %%
# %sql
SELECT * FROM databricks_assesment.bronze.stream_bronze_trade_events
ORDER BY _ingested_at DESC;

# %%
# %sql
SELECT
  symbol,
  COUNT(*) AS trades,
  SUM(trade_value) AS gross_value
FROM databricks_assesment.silver.stream_silver_trades
GROUP BY symbol
ORDER BY gross_value DESC;
