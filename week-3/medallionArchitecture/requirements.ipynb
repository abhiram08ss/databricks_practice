# %%
# %sql
SELECT current_catalog()

# %%
# %sql
CREATE CATALOG IF NOT EXISTS medallion_catalog;

# %%
# %sql

SHOW STORAGE CREDENTIALS;

# %%
# %sql
CREATE EXTERNAL LOCATION landing_location
URL 'abfss://medallion@abhiramblobstorage.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL datastorage_azuremanagedidentity_1786963728627);

# %%
# %sql
use catalog medallion_catalog

# %%
# %sql
SELECT current_catalog()

# %%
%

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS medallion_catalog.landing
MANAGED LOCATION 'abfss://medallion@abhiramblobstorage.dfs.core.windows.net/landing';

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS medallion_catalog.bronze
MANAGED LOCATION 'abfss://medallion@abhiramblobstorage.dfs.core.windows.net/bronze';

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS medallion_catalog.silver
MANAGED LOCATION 'abfss://medallion@abhiramblobstorage.dfs.core.windows.net/silver';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS medallion_catalog.gold
MANAGED LOCATION 'abfss://medallion@abhiramblobstorage.dfs.core.windows.net/gold';

# %%
# %sql

CREATE VOLUME IF NOT EXISTS medallion_catalog.landing.landing_volume
